# %% [markdown]
# ## Purpose of the notebook
#
# This notebook plots time steps for loaded raw data in order to check the sampling rate irregularities.

# %%
import sys

sys.path.insert(
    1, "..\\utilities\\"
)  # adds utilities folder to path so we can import modules from it, won't be needed after packaging

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import loading_utils as load

# %%
# This is a block for making participant dataframes from raw files in directory data_dir (here Windows path to retinawise mirror folder on drive)
# It saves the participant dfs into directory defined in save_path (about 300 - 400 MB per participant), format 2xx_recording_data.csv
# Uncomment and run if you don't have these dataframes (remember that the folder specified in save_path must exist)
# data_dir = "D:/retinawise_mirror/raw/"
# save_path = './results/'
# for participant_id in participant_list:
#     data_df, protocol_timecourse_df, protocol_vars_df = load.load_participant_data(participant_no=participant_id,
#                                                                                    data_dir=data_dir,
#                                                                                    include_failed=False,
#                                                                                    save=True,
#                                                                                    save_path=save_path)

# %%
participant_id = 200
data_dir = "./results/new/"
data_path = os.path.join(data_dir, str(participant_id) + "_recording_data.csv")

data_df = pd.read_csv(data_path)
data_df["Time diff"] = data_df["Overall time Sec"].diff() * 1000  # in ms
data_df.loc[data_df["Time diff"] < 0, "Time diff"] = (
    np.nan
)  # to avoid a negative jump from recording to recording
data_df_notna = data_df[data_df["Stim eye - Size Mm"].notna()].copy()
data_df_notna["Time diff"] = data_df_notna["Overall time Sec"].diff() * 1000
data_df_notna.loc[data_df_notna["Time diff"] < 0, "Time diff"] = np.nan

for id in data_df["Recording id"].unique():
    print(f"Time steps for participant {participant_id}, recording {id}")
    print(
        f"With nan: max: {data_df['Time diff'][(data_df['Recording id']==id)].max()},min: {data_df['Time diff'][(data_df['Recording id']==id)].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id)].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id)].std()}"
    )

    binrange_notna = [0, data_df_notna["Time diff"][(data_df_notna["Recording id"] == id)].max()]
    binrange = [0, data_df["Time diff"][(data_df["Recording id"] == id)].max()]
    f, (ax1, ax2) = plt.subplots(
        1, 2, gridspec_kw={"width_ratios": [1, 1]}, figsize=(7, 3)
    )

    print(
        f"Without nan: max: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].max()},min: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].min()},mean: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].mean()},stdev: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].std()}"
    )
    sns.histplot(
        ax=ax1,
        data=data_df_notna[(data_df_notna["Recording id"] == id)],
        x="Time diff",
        binwidth=1,
        binrange=binrange_notna,
    )

    ax1.set_title(f"Stim eye without nans")
    ax1.set_xlabel("Time step [ms]")
    sns.histplot(
        ax=ax2,
        data=data_df[data_df["Recording id"] == id],
        x="Time diff",
        binwidth=1,
        binrange=binrange,
    )
    ax2.set_title("Stim eye with nans")
    ax2.set_xlabel("Time step[ms]")
    f.suptitle(f"Recording {id},participant {participant_id}")
    plt.tight_layout()

    plt.show()
# Out:
# Time steps for participant 200, recording 0
# With nan: max: 72.00000000000273,min: 0.0,mean: 17.097499941532778,stdev: 10.471842777350917
# Without nan: max: 202.99999999997453,min: 1.9999999999527063,mean: 34.083826751829925,stdev: 3.964543993674195
# Time steps for participant 200, recording 3
# With nan: max: 81.99999999999363,min: 0.0,mean: 17.022979139504567,stdev: 10.231692679541158
# Without nan: max: 305.9999999999974,min: 0.0,mean: 34.114408361328856,stdev: 4.186371824410032
# Time steps for participant 200, recording 4
# With nan: max: 82.99999999996999,min: 0.0,mean: 17.276278476226487,stdev: 11.054143684572603
# Without nan: max: 341.99999999998454,min: 6.999999999948159,mean: 34.10543503615582,stdev: 4.161723889439663
# Time steps for participant 200, recording 5
# With nan: max: 86.00000000001273,min: 0.0,mean: 17.361814295891712,stdev: 11.051821479656127
# Without nan: max: 272.00000000000557,min: 4.000000000019099,mean: 34.10107747562853,stdev: 4.0001280714076275
# Time steps for participant 200, recording 6
# With nan: max: 156.0000000000059,min: 0.0,mean: 17.19153989042771,stdev: 10.439635004482684
# Without nan: max: 469.99999999997044,min: 2.999999999985903,mean: 34.17650633384752,stdev: 6.6191453296816745
# Time steps for participant 200, recording 7
# With nan: max: 76.99999999999818,min: 0.0,mean: 17.336874303464302,stdev: 11.09535578148548
# Without nan: max: 242.999999999995,min: 7.000000000005002,mean: 34.12612023898431,stdev: 4.019262441586337
# Time steps for participant 200, recording 8
# With nan: max: 76.00000000002183,min: 0.0,mean: 17.20493269321284,stdev: 10.719532058943445
# Without nan: max: 168.00000000000637,min: 8.000000000038199,mean: 34.056181869002145,stdev: 3.31949780430263
# Time steps for participant 200, recording 10
# With nan: max: 62.99999999998818,min: 0.0,mean: 17.182627905337124,stdev: 10.68756792137321
# Without nan: max: 209.00000000000318,min: 7.999999999995566,mean: 34.05766991195789,stdev: 3.8285887847589644
# Time steps for participant 200, recording 11
# With nan: max: 89.99999999991815,min: 0.0,mean: 16.931428174428568,stdev: 9.441359885613831
# Without nan: max: 239.00000000003274,min: 7.999999999981355,mean: 34.08307692307692,stdev: 3.9458309207611117
# Time steps for participant 200, recording 12
# With nan: max: 84.9999999999227,min: 0.0,mean: 17.164170344633295,stdev: 10.523100717444132
# Without nan: max: 235.99999999999,min: 3.0000000000427463,mean: 34.063271676839214,stdev: 3.9399442634066806
# Time steps for participant 200, recording 13
# With nan: max: 81.99999999999363,min: 0.0,mean: 17.130652795351235,stdev: 10.483542681328363
# Without nan: max: 510.9999999999957,min: 7.999999999981355,mean: 34.276665572694455,stdev: 7.48618506487522
# Time steps for participant 200, recording 14
# With nan: max: 67.99999999998363,min: 0.0,mean: 17.055240627988894,stdev: 10.100795136272447
# Without nan: max: 341.99999999998454,min: 5.999999999971806,mean: 34.224427695332615,stdev: 5.934387242917627
# Time steps for participant 200, recording 15
# With nan: max: 86.00000000001273,min: 0.0,mean: 16.95475312507247,stdev: 10.172028728468288
# Without nan: max: 2221.0000000000036,min: 8.000000000038199,mean: 34.404687941259525,stdev: 18.921042779844694
# Time steps for participant 200, recording 16
# With nan: max: 63.00000000010186,min: 0.0,mean: 16.899056909065695,stdev: 10.089798358614269
# Without nan: max: 615.0000000000091,min: 6.999999999948159,mean: 34.277944486121534,stdev: 9.136108765876578
# Time steps for participant 200, recording 17
# With nan: max: 81.99999999999363,min: 0.0,mean: 17.3117762674939,stdev: 11.028989453078594
# Without nan: max: 206.99999999999363,min: 1.9999999999527063,mean: 34.06229615133725,stdev: 3.6306177581374435
# Time steps for participant 200, recording 18
# With nan: max: 67.99999999998363,min: 0.0,mean: 17.13816869051526,stdev: 10.66626113539702
# Without nan: max: 165.99999999999682,min: 6.999999999948159,mean: 34.057160160253424,stdev: 3.3788566113640086
# Time steps for participant 200, recording 19
# With nan: max: 96.00000000000364,min: 0.0,mean: 17.07785018569126,stdev: 10.562060519931103
# Without nan: max: 270.99999999995816,min: 5.999999999971806,mean: 34.09499160604365,stdev: 4.109967104410429
# Time steps for participant 200, recording 23
# With nan: max: 103.00000000006548,min: 0.0,mean: 17.08066092209292,stdev: 10.574762144402952
# Without nan: max: 2186.0000000000355,min: 4.000000000019099,mean: 34.28854151728094,stdev: 15.644735152634325
# Time steps for participant 200, recording 24
# With nan: max: 67.00000000000728,min: 0.0,mean: 17.24531194716358,stdev: 10.955048412205583
# Without nan: max: 240.0000000000091,min: 0.9999999999763531,mean: 34.1139937473753,stdev: 4.148461156964458
# Time steps for participant 200, recording 25
# With nan: max: 309.0000000000259,min: 0.0,mean: 17.487920972062764,stdev: 12.037202738550006
# Without nan: max: 312.9999999999882,min: 0.9999999999763531,mean: 34.35543442507401,stdev: 8.952195235275358
# Time steps for participant 200, recording 26
# With nan: max: 1039.999999999992,min: 0.0,mean: 17.116019383383662,stdev: 12.076694283042242
# Without nan: max: 1039.999999999992,min: 0.999999999990564,mean: 34.12026320701885,stdev: 8.749873041009884
# Time steps for participant 200, recording 27
# With nan: max: 73.00000000003593,min: 0.0,mean: 17.035812479612282,stdev: 10.117431465837248
# Without nan: max: 145.00000000001023,min: 6.999999999948159,mean: 34.05743967203951,stdev: 3.313597598064845
# Time steps for participant 200, recording 28
# With nan: max: 233.00000000006094,min: 0.0,mean: 17.105992185123657,stdev: 10.356091338499573
# Without nan: max: 452.99999999997453,min: 1.0000000000012221,mean: 34.129172307548664,stdev: 5.000819635084061

# %%
participant_id = 209
data_dir = "./results/new/"
data_path = os.path.join(data_dir, str(participant_id) + "_recording_data.csv")

data_df = pd.read_csv(data_path)
data_df["Time diff"] = data_df["Overall time Sec"].diff() * 1000  # in ms
data_df.loc[data_df["Time diff"] < 0, "Time diff"] = (
    np.nan
)  # to avoid a negative jump from recording to recording
data_df_notna = data_df[data_df["Stim eye - Size Mm"].notna()].copy()
data_df_notna["Time diff"] = data_df_notna["Overall time Sec"].diff() * 1000
data_df_notna.loc[data_df_notna["Time diff"] < 0, "Time diff"] = np.nan

for id in data_df["Recording id"].unique():
    print(f"Time steps for participant {participant_id}, recording {id}")
    print(
        f"With nan: max: {data_df['Time diff'][(data_df['Recording id']==id)].max()},min: {data_df['Time diff'][(data_df['Recording id']==id)].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id)].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id)].std()}"
    )

    binrange = [0, data_df["Time diff"][(data_df["Recording id"] == id)].max()]
    f, (ax1, ax2) = plt.subplots(
        1, 2, gridspec_kw={"width_ratios": [1, 1]}, figsize=(7, 3)
    )

    print(
        f"Without nan: max: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].max()},min: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].min()},mean: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].mean()},stdev: {data_df_notna['Time diff'][(data_df_notna['Recording id']==id)].std()}"
    )
    sns.histplot(
        ax=ax1,
        data=data_df_notna[(data_df_notna["Recording id"] == id)],
        x="Time diff",
        binwidth=1,
        binrange=binrange,
    )

    ax1.set_title(f"Stim eye without nans")
    ax1.set_xlabel("Time step [ms]")
    sns.histplot(
        ax=ax2,
        data=data_df[data_df["Recording id"] == id],
        x="Time diff",
        binwidth=1,
        binrange=binrange,
    )
    ax2.set_title("Stim eye with nans")
    ax2.set_xlabel("Time step[ms]")
    f.suptitle(f"Recording {id},participant {participant_id}")
    plt.tight_layout()

    plt.show()

# %%
for id in data_df["Recording id"].unique():

    f, (ax1) = plt.subplots(1, 1, figsize=(12, 3))

    sns.scatterplot(
        data=data_df[data_df["Recording id"] == id],
        x="Overall time Sec",
        y="Time diff",
        s=0.5,
    )
    ax1.set_title(f"Time step course with nans")
    ax1.set_xlabel("Overall time [s]")
    ax1.set_ylabel("Time step [ms]")

    f.suptitle(f"Recording {id},participant {participant_id}")
    plt.tight_layout()

    plt.show()
