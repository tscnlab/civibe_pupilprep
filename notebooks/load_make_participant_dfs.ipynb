# %% [markdown]
# ### This is a notebook for creation of full recording participant dataframes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import loading_utils as load

# %%
data_dir = "D:\\retinawise_mirror\\raw"

participant_list = [200, 201, 202, 204, 205, 206, 207, 209, 210, 211, 212, 213]
for participant_no in participant_list:
    data_df, protocol_timecourse_df, protocol_vars_df = load.load_participant_data(
        participant_no,
        data_dir,
        delay=0,
        include_failed=False,
        save=False,
        save_path="./results/new/",
    )

# %%
data_df
# Out:
#         index  Overall time Sec  Sequence time Sec Experiment state  \
# 0           0             0.012              0.013           Active
# 1           1             0.016              0.017           Active
# 2           2             0.029              0.030           Active
# 3           3             0.038              0.039           Active
# 4           4             0.066              0.067           Active
# ...       ...               ...                ...              ...
# 968925  42892           731.050             19.370           Active
# 968926  42893           731.074             19.394           Active
# 968927  42894           731.087             19.407           Active
# 968928  42895           731.105             19.425           Active
# 968929  42896           731.118             19.438           Active
#
#         Sequence index  Sequences count  Excitation index  \
# 0                    1               26               2.0
# 1                    1               26               2.0
# 2                    1               26               2.0
# 3                    1               26               2.0
# 4                    1               26               2.0
# ...                ...              ...               ...
# 968925              26               26            3852.0
# 968926              26               26            3852.0
# 968927              26               26            3852.0
# 968928              26               26            3852.0
# 968929              26               26            3852.0
#
#        Excitation label - Left Excitation label - Right  Left - Is found  ...  \
# 0                     baseline                     dark            False  ...
# 1                     baseline                     dark            False  ...
# 2                     baseline                     dark            False  ...
# 3                     baseline                     dark            False  ...
# 4                     baseline                     dark            False  ...
# ...                        ...                      ...              ...  ...
# 968925                baseline                     dark             True  ...
# 968926                baseline                     dark            False  ...
# 968927                baseline                     dark             True  ...
# 968928                baseline                     dark            False  ...
# 968929                baseline                     dark             True  ...
#
#                                                  Filepath  Recording id  \
# 0       D:\retinawise_mirror\raw\204\03_expsession\ret...             1
# 1       D:\retinawise_mirror\raw\204\03_expsession\ret...             1
# 2       D:\retinawise_mirror\raw\204\03_expsession\ret...             1
# 3       D:\retinawise_mirror\raw\204\03_expsession\ret...             1
# 4       D:\retinawise_mirror\raw\204\03_expsession\ret...             1
# ...                                                   ...           ...
# 968925  D:\retinawise_mirror\raw\204\03_expsession\ret...            24
# 968926  D:\retinawise_mirror\raw\204\03_expsession\ret...            24
# 968927  D:\retinawise_mirror\raw\204\03_expsession\ret...            24
# 968928  D:\retinawise_mirror\raw\204\03_expsession\ret...            24
# 968929  D:\retinawise_mirror\raw\204\03_expsession\ret...            24
#
#         Participant id  Block  Test  Trial phase  Trial type  Trial no  \
# 0                  204      0     a   Adaptation         N/A       NaN
# 1                  204      0     a   Adaptation         N/A       NaN
# 2                  204      0     a   Adaptation         N/A       NaN
# 3                  204      0     a   Adaptation         N/A       NaN
# 4                  204      0     a   Adaptation         N/A       NaN
# ...                ...    ...   ...          ...         ...       ...
# 968925             204     10     b    post-stim        flux       575
# 968926             204     10     b    post-stim        flux       575
# 968927             204     10     b    post-stim        flux       575
# 968928             204     10     b    post-stim        flux       575
# 968929             204     10     b    post-stim        flux       575
#
#         Trial time Sec  Stim eye - Size Mm
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ...                ...                 ...
# 968925          19.353             4.18849
# 968926          19.377                 NaN
# 968927           19.39             4.19326
# 968928          19.408                 NaN
# 968929          19.421             4.19836
#
# [968930 rows x 38 columns]
