# %% [markdown]
# ### This is a notebook for creation of full recording participant dataframes.

# %%
import sys
sys.path.insert(1, '..\\utilities\\') #adds utilities folder to path so we can import modules from it, won't be needed after packaging

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import loading_utils as load

# %%
data_dir = 'D:\\retinawise_mirror\\raw'

participant_list=[200,201,202,205,206,207,209,210,211,212,213]
for participant_no in participant_list:
    data_df,protocol_timecourse_df,protocol_vars_df = load.load_participant_data(participant_no,data_dir,include_failed=False,save=False,save_path='./results/new/')

# %%
data_df
# Out:
#         index  Overall time Sec  Sequence time Sec Experiment state  \
# 0           0             0.002              0.003           Active
# 1           1             0.008              0.009           Active
# 2           2             0.008              0.009           Active
# 3           3             0.029              0.030           Active
# 4           4             0.043              0.043           Active
# ...       ...               ...                ...              ...
# 945949  42494           731.061             19.377           Active
# 945950  42495           731.085             19.401           Active
# 945951  42496           731.096             19.412           Active
# 945952  42497           731.120             19.436           Active
# 945953  42498           731.125             19.441           Active
#
#         Sequence index  Sequences count  Excitation index  \
# 0                    1               26               2.0
# ...
