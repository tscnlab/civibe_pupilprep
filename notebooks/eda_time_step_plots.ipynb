# %%
import sys

sys.path.insert(
    1, "..\\utilities\\"
)  # adds utilities folder to path so we can import modules from it, won't be needed after packaging

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import loading_utils as load

# %%
participant_id = 200
data_dir = "./results/new/"
data_path = os.path.join(data_dir, str(participant_id) + "_recording_data.csv")

data_df = pd.read_csv(data_path)
data_df["Time diff"] = data_df["Overall time Sec"].diff() * 1000  # in ms
data_df.loc[data_df["Time diff"] < 0, "Time diff"] = (
    np.nan
)  # to avoid a negative jump from recording to recording


for id in data_df["Recording id"].unique():
    print(f"Time steps for participant {participant_id}, recording {id}")
    print(
        f"With nan: max: {data_df['Time diff'][(data_df['Recording id']==id)].max()},min: {data_df['Time diff'][(data_df['Recording id']==id)].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id)].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id)].std()}"
    )

    binrange = [0, data_df["Time diff"][(data_df["Recording id"] == id)].max()]
    f, (ax1, ax2) = plt.subplots(
        1, 2, gridspec_kw={"width_ratios": [1, 1]}, figsize=(7, 3)
    )
    if data_df.loc[data_df["Recording id"] == id, "Eye"].values[0] == "L":
        print(
            f"Without nan: max: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].max()},min: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].std()}"
        )
        sns.histplot(
            ax=ax1,
            data=data_df[
                (data_df["Recording id"] == id) & (data_df["Left - RadiusB Px"].notna())
            ],
            x="Time diff",
            binwidth=1,
            binrange=binrange,
        )

    else:
        print(
            f"Without nan: max: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].max()},min: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].std()}"
        )
        sns.histplot(
            ax=ax1,
            data=data_df[
                (data_df["Recording id"] == id)
                & (data_df["Right - RadiusB Px"].notna())
            ],
            x="Time diff",
            binwidth=1,
            binrange=binrange,
        )

    ax1.set_title(f"Stim eye without nans")
    ax1.set_xlabel("Time step [ms]")
    sns.histplot(
        ax=ax2,
        data=data_df[data_df["Recording id"] == id],
        x="Time diff",
        binwidth=1,
        binrange=binrange,
    )
    ax2.set_title("Stim eye with nans")
    ax2.set_xlabel("Time step[ms]")
    f.suptitle(f"Recording {id},participant {participant_id}")
    plt.tight_layout()

    plt.show()
# Out:
# Time steps for participant 200, recording 0
# With nan: max: 72.00000000000273,min: 0.0,mean: 17.097499941532778,stdev: 10.471842777350917
# Without nan: max: 72.00000000000273,min: 0.0,mean: 19.005454545454647,stdev: 10.674567968568843
# Time steps for participant 200, recording 3
# With nan: max: 81.99999999999363,min: 0.0,mean: 17.022979139504567,stdev: 10.231692679541158
# Without nan: max: 81.99999999999363,min: 0.0,mean: 17.597396538048862,stdev: 10.591790556349375
# Time steps for participant 200, recording 4
# With nan: max: 82.99999999996999,min: 0.0,mean: 17.276278476226487,stdev: 11.054143684572603
# Without nan: max: 82.99999999996999,min: 0.0,mean: 17.27103937301717,stdev: 11.493402862737451
# Time steps for participant 200, recording 5
# With nan: max: 86.00000000001273,min: 0.0,mean: 17.361814295891712,stdev: 11.051821479656127
# Without nan: max: 86.00000000001273,min: 0.0,mean: 18.50144589552229,stdev: 11.437575489740263
# Time steps for participant 200, recording 6
# ...

# %%
participant_id = 209
data_dir = "./results/new/"
data_path = os.path.join(data_dir, str(participant_id) + "_recording_data.csv")

data_df = pd.read_csv(data_path)
data_df["Time diff"] = data_df["Overall time Sec"].diff() * 1000  # in ms
data_df.loc[data_df["Time diff"] < 0, "Time diff"] = (
    np.nan
)  # to avoid a negative jump from recording to recording


for id in data_df["Recording id"].unique():
    print(f"Time steps for participant {participant_id}, recording {id}")
    print(
        f"With nan: max: {data_df['Time diff'][(data_df['Recording id']==id)].max()},min: {data_df['Time diff'][(data_df['Recording id']==id)].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id)].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id)].std()}"
    )

    binrange = [0, data_df["Time diff"][(data_df["Recording id"] == id)].max()]
    f, (ax1, ax2) = plt.subplots(
        1, 2, gridspec_kw={"width_ratios": [1, 1]}, figsize=(7, 3)
    )
    if data_df.loc[data_df["Recording id"] == id, "Eye"].values[0] == "L":
        print(
            f"Without nan: max: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].max()},min: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Left - RadiusB Px'].notna())].std()}"
        )
        sns.histplot(
            ax=ax1,
            data=data_df[
                (data_df["Recording id"] == id) & (data_df["Left - RadiusB Px"].notna())
            ],
            x="Time diff",
            binwidth=1,
            binrange=binrange,
        )

    else:
        print(
            f"Without nan: max: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].max()},min: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].min()},mean: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].mean()},stdev: {data_df['Time diff'][(data_df['Recording id']==id) &(data_df['Right - RadiusB Px'].notna())].std()}"
        )
        sns.histplot(
            ax=ax1,
            data=data_df[
                (data_df["Recording id"] == id)
                & (data_df["Right - RadiusB Px"].notna())
            ],
            x="Time diff",
            binwidth=1,
            binrange=binrange,
        )

    ax1.set_title(f"Stim eye without nans")
    ax1.set_xlabel("Time step [ms]")
    sns.histplot(
        ax=ax2,
        data=data_df[data_df["Recording id"] == id],
        x="Time diff",
        binwidth=1,
        binrange=binrange,
    )
    ax2.set_title("Stim eye with nans")
    ax2.set_xlabel("Time step[ms]")
    f.suptitle(f"Recording {id},participant {participant_id}")
    plt.tight_layout()

    plt.show()
# Out:
# Time steps for participant 209, recording 0
# With nan: max: 52.00000000002092,min: 0.0,mean: 16.808262638802677,stdev: 10.418532442024993
# Without nan: max: 48.99999999997817,min: 0.0,mean: 15.35082604470349,stdev: 10.007725112576981
# Time steps for participant 209, recording 1
# With nan: max: 56.00000000000094,min: 0.0,mean: 16.895225770670606,stdev: 10.505259527934983
# Without nan: max: 56.00000000000094,min: 0.0,mean: 18.627664298401267,stdev: 10.627242864034692
# Time steps for participant 209, recording 2
# With nan: max: 60.000000000002274,min: 0.0,mean: 16.8442345351918,stdev: 10.378763538986727
# Without nan: max: 60.000000000002274,min: 0.0,mean: 17.602918388430595,stdev: 10.08148368649124
# Time steps for participant 209, recording 4
# With nan: max: 86.99999999998909,min: 0.0,mean: 16.89092463379696,stdev: 10.430186961668985
# Without nan: max: 86.99999999998909,min: 0.0,mean: 16.132336343115842,stdev: 10.997914476480982
# Time steps for participant 209, recording 5
# ...

# %%
for id in data_df["Recording id"].unique():

    f, (ax1) = plt.subplots(1, 1, figsize=(12, 3))

    sns.scatterplot(
        data=data_df[data_df["Recording id"] == id],
        x="Overall time Sec",
        y="Time diff",
        s=0.5,
    )
    ax1.set_title(f"Time step course with nans")
    ax1.set_xlabel("Overall time [s]")
    ax1.set_ylabel("Time step [ms]")

    f.suptitle(f"Recording {id},participant {participant_id}")
    plt.tight_layout()

    plt.show()
