# %% [markdown]
# ### This is a notebook for creation of full recording participant dataframes.

# %%
import sys
sys.path.insert(1, '..\\utilities\\') #adds utilities folder to path so we can import modules from it, won't be needed after packaging

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import loading_utils as load

# %%
data_dir = 'D:\\retinawise_mirror\\raw'
participant_no = 200
data_df,protocol_timecourse_df,protocol_vars_df = load.load_participant_data(participant_no,data_dir,include_failed=False,save=False)

# %%
data_df
# Out:
#        Overall time Sec  Sequence time Sec Experiment state  Sequence index  \
# 0                 0.005              0.005           Active               1
# 1                 0.011              0.012           Active               1
# 2                 0.013              0.014           Active               1
# 3                 0.017              0.018           Active               1
# 4                 0.037              0.038           Active               1
# ...                 ...                ...              ...             ...
# 42735           731.016             19.366           Active              26
# 42736           731.017             19.366           Active              26
# 42737           731.051             19.401           Active              26
# 42738           731.085             19.434           Active              26
# 42739           731.097             19.446           Active              26
#
#        Sequences count  Excitation index Excitation label - Left  \
# 0                   26               2.0                    dark
# 1                   26               2.0                    dark
# 2                   26               2.0                    dark
# 3                   26               2.0                    dark
# 4                   26               2.0                    dark
# ...                ...               ...                     ...
# 42735               26            3852.0                    dark
# 42736               26            3852.0                    dark
# 42737               26            3852.0                    dark
# 42738               26            3852.0                    dark
# 42739               26            3852.0                    dark
#
#       Excitation label - Right  Left - Is found  Left - Size Mm  ...  \
# 0                     baseline            False             NaN  ...
# 1                     baseline            False             NaN  ...
# 2                     baseline            False             NaN  ...
# 3                     baseline             True         7.08888  ...
# 4                     baseline            False             NaN  ...
# ...                        ...              ...             ...  ...
# 42735                 baseline             True         5.82548  ...
# 42736                 baseline            False             NaN  ...
# 42737                 baseline             True         5.84456  ...
# 42738                 baseline             True         5.85972  ...
# 42739                 baseline            False             NaN  ...
#
#        Right - Area Mm  Right - RadiusA Px  Right - RadiusB Px  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2             48.34954           154.75278           195.26927
# 3                  NaN                 NaN                 NaN
# 4             48.20251           154.62114           194.84119
# ...                ...                 ...                 ...
# 42735              NaN                 NaN                 NaN
# 42736         38.84994           136.29063           178.15761
# 42737         38.88198           136.25307           178.35370
# 42738         38.95032           136.25311           178.66711
# 42739              NaN                 NaN                 NaN
#
#        Right - PosX Px  Right - PoxY Px  Right - Distance from focus  \
# 0                  NaN              NaN                          NaN
# 1                  NaN              NaN                          NaN
# 2            375.10013        585.06671                     59.19524
# 3                  NaN              NaN                          NaN
# 4            375.21579        585.48529                     59.45891
# ...                ...              ...                          ...
# 42735              NaN              NaN                          NaN
# 42736        302.99979        555.55981                    109.41843
# 42737        301.92145        555.05872                    110.40439
# 42738        301.61502        554.46704                    110.61753
# 42739              NaN              NaN                          NaN
#
#        Right - Leds temp  Eye       Phase  Session id
# 0                    NaN    R  Adaptation           0
# 1                    NaN    R  Adaptation           0
# 2                    NaN    R  Adaptation           0
# 3                    NaN    R  Adaptation           0
# 4                    NaN    R  Adaptation           0
# ...                  ...  ...         ...         ...
# 42735                NaN    R    pre-stim          28
# 42736                NaN    R    pre-stim          28
# 42737                NaN    R    pre-stim          28
# 42738                NaN    R    pre-stim          28
# 42739            26.3463    R    pre-stim          28
#
# [1018501 rows x 29 columns]
